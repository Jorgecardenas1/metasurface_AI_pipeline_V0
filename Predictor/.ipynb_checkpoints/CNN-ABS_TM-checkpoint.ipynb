# %%
import sys  
sys.path.insert(0, '../../druida_V01/src/')

import os

from __future__ import print_function
#from Utilities.SaveAnimation import Video



from druida import Stack
from druida import setup

from druida.DataManager import datamanager
from druidaHFSS.modules import tools
from druida.tools import utils

import random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.optim as optimizer

from torchsummary import summary
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from torcheval.metrics import BinaryAccuracy

from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor, Lambda
import torchvision.utils as vutils


import matplotlib.pyplot as plt
import matplotlib.animation as animation

from IPython.display import HTML

from glob import glob

import argparse

# %%
torch.set_printoptions(profile="full")
torch.manual_seed(999)

# %%
parser = argparse.ArgumentParser()

parser.add_argument("run_name",type=str)
parser.add_argument("epochs",type=int)
parser.add_argument("batch_size",type=int)
parser.add_argument("workers",type=int)
parser.add_argument("gpu_number",type=int)
parser.add_argument("device",type=str)
parser.add_argument("learning_rate",type=float)

parser.run_name = "DDPM_Uncondtional"
parser.epochs = 3
parser.batch_size = 5
parser.workers=0
parser.gpu_number=0
parser.image_size = 512
parser.dataset_path = os.path.normpath('/content/drive/MyDrive/Training_Data/Training_lite/')
parser.device = "cpu"
parser.learning_rate = 5e-6


condition_len=10

# %% [markdown]
# ## 1. Preprocessing

# %%
imagesPath="C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\"

# %%
folders=glob(imagesPath+"/*/", recursive = True)
files=[]

print(folders)
for folder in folders:
    
    if folder != imagesPath+"\\"+ "processed\\":
        files=(files+glob(folder+"/*"))
# Out:
# ['C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\09a2f2c2-ad7f-11ee-bb2a-047c16a08772\\', 'C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\0ed3a0e8-a653-11ee-9db6-047c16a08772\\', 'C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\62cb3644-a81d-11ee-982e-047c16a08772\\', 'C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\7262ded2-a81d-11ee-8e0e-047c16a08772\\', 'C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\a824dcc3-a766-11ee-a27c-047c16a08772\\', 'C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\b6b02fee-a8bb-11ee-8e20-047c16a08772\\', 'C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\c49e201f-ae96-11ee-88f3-047c16a08772\\', 'C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\d31e1e9f-a766-11ee-8b8e-047c16a08772\\', 'C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\e3744294-aba9-11ee-b4d0-047c16a08772\\', 'C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\e7a929dd-afb8-11ee-bc36-047c16a08772\\', 'C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images\\ed120727-a5ab-11ee-947e-047c16a08772\\']

# %%
for file in files:
    fileName_absolute = os.path.basename(file) 
    path=os.path.dirname(file)

    #ROI is 
    image_rgb=tools.cropImage( file,image_path=path,
                              image_name=fileName_absolute,
                              output_path=imagesPath, 
                             resize_dim=(512,512))
# Out:
# The new directory is created!

# %% [markdown]
# ## Load Images

# %%
boxImagesPath="C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Images Jorge Cardenas 512\\"
DataPath="C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\Exports\\output\\"

# %%
dataloader = utils.get_data_with_labels(512, 512,0.95, boxImagesPath,parser.batch_size, drop_last=True)
print(len(dataloader))
#Visualizing one item
#for data,classes,_ in dataloader:
 #   print(len(data))
#in this case we can have access to every image name match with 
#other kind of data 
data,target,path = next(iter(dataloader))

image = data.detach().cpu().permute(0, 2, 3,1).numpy()
images = (image * 255).round().astype("uint8")

pil_images = images
pil_images[0]

import matplotlib.pyplot as plt
plt.figure(figsize=(3,3))
plt.imshow(pil_images[0])
plt.show
# Out:
# 556
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
images.shape
# Out:
# (5, 512, 512, 3)

# %%
import torch.nn.functional as F
import torchvision
import torchvision


class FWD(nn.Module):
    def __init__(self, cond_input_size, ngpu=0, image_size=512 , output_size=0, channels=3):
        super(FWD, self).__init__()

        
        self.checkDevice()

        self.ngpu = ngpu            
        self.image_size = image_size
        self.channels = channels


        self.l1 = nn.Linear(cond_input_size, image_size*image_size*channels, bias=False)           
        self.conv1 = nn.Conv2d(2*channels, output_size, 6, 2, 4, bias=False) 
        self.conv2 = nn.LeakyReLU(0.2, inplace=True)
        self.conv3 = nn.Conv2d(output_size, output_size * 2, 6, 2, 5, bias=False)
        self.conv4 = nn.BatchNorm2d(output_size * 2)
        self.conv5 = nn.LeakyReLU(0.2, inplace=True)
        self.conv6 = nn.Conv2d(output_size * 2, output_size * 4, 6, 2, 4, bias=False)
        self.conv7 = nn.BatchNorm2d(output_size * 4)
        self.conv8 = nn.LeakyReLU(0.2, inplace=True)
        self.conv9 = nn.Conv2d(output_size * 4, output_size * 8, 6, 2, 2, bias=False)
        self.conv10 = nn.BatchNorm2d(output_size * 8)
        self.conv11 = nn.LeakyReLU(0.2, inplace=True)
        self.conv12 = nn.Conv2d(output_size * 8, output_size * 16, 2, 1, 0, bias=False)

        
        #Here we apply a flattening
        self.l2 = nn.Linear(139392, 3000, bias=False)           
        #self.dropout1 = nn.Dropout(0.2)
        #self.l3 = nn.Linear(5000, 1000, bias=False)           
        self.dropout2 = nn.Dropout(0.2)
        self.l4 = nn.Linear(3000, 601, bias=False)           





    def forward(self, input_, conditioning, b_size):
        x1 = input_
        x2 = self.l1(conditioning) #Size must be taken care = 800 in this case
        #the output is imagesize x imagesize x channel
        #hence the need of reshape 

        if self.ngpu == 0 :
        
            x2 = x2.reshape(int(b_size),self.channels,self.image_size,self.image_size) 
        else:
            x2 = x2.reshape(int(b_size/self.ngpu),self.channels,self.image_size,self.image_size) 
        
        #print(x1.shape)
        #print(x2.shape)
        combine = torch.cat((x1,x2),dim=1) # concatenate in a given dimension
        #esto viene del mismo paper sobre los CGAN
        outmap_min, _ = torch.min(combine, dim=1, keepdim=True)
        outmap_max, _ = torch.max(combine, dim=1, keepdim=True)
        combine = (combine - outmap_min) / (outmap_max - outmap_min) # Broadcasting rules apply

        combine = self.conv1(combine) #This conv1 considers 2 x channels from the combine
        combine = self.conv2(combine)
        combine = self.conv3(combine)
        combine = self.conv4(combine)
        combine = self.conv5(combine)
        
        combine = self.conv6(combine)
        combine = self.conv7(combine)
        combine = self.conv8(combine)
        combine = self.conv9(combine)
        combine = self.conv10(combine)
        combine = self.conv11(combine)
        combine = self.conv12(combine)
        #print(combine.shape)

        combine =combine.view(combine.size(0), -1)

        combine = self.l2(combine)
        #combine = self.dropout1(combine)
        #combine = self.l3(combine)
        combine = self.dropout2(combine)

        combine = self.l4(combine)

        combine = F.softmax(combine, dim=1)


        return combine

    def checkDevice(self):
        self.device = (
        "cuda"
        if torch.cuda.is_available()
        else "mps"
        if torch.backends.mps.is_available()
        else "cpu"
        )

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv2d') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
#Example of a conditioning shape
conditioning=torch.ones(1,parser.batch_size,condition_len)
conditioning.shape
# Out:
# torch.Size([1, 5, 10])

# %% [markdown]
# ## loading and comparing data

# %%
import matplotlib.pyplot as plt
import glob
from tqdm.notebook import tqdm
import torch.optim as optimizer
import glob




beta1 = 0.5

#File reading conf
a = []
idx=0
metricType='AbsorbanceTM'

#training conf
iters=0

fwd_test = FWD(cond_input_size=condition_len,output_size=8)
fwd_test.apply(weights_init)
#opt=optimizer.SGD(fwd_test.parameters(), lr=parser.learning_rate, momentum=0.9)
opt = optimizer.Adam(fwd_test.parameters(), lr=parser.learning_rate, betas=(beta1, 0.999),weight_decay=1e-4)
#criterion = nn.BCELoss()
criterion = nn.CrossEntropyLoss()
fwd_test.train()

for epoch in range(parser.epochs):
    x=0
    running_loss = 0.0
    loss_values = []
    i=0
    print('Epoch {}/{}'.format(epoch, parser.epochs - 1))
    print('-' * 10)
    
    
    dataloader = utils.get_data_with_labels(512, 512,0.9, boxImagesPath,parser.batch_size,drop_last=True)


    for data in tqdm(dataloader):
        
        
        inputs, classes, names = data
        
        opt.zero_grad()
        
        #Loading data
        a = []
        idx=0
        
        
        for name in names:
            series=name.split('_')[-1].split('.')[0]
            batch=name.split('_')[4]
            for name in glob.glob(DataPath+batch+'\\files\\'+'/'+metricType+'*'+series+'.csv'): 
                #loading the absorption data
                train = pd.read_csv(name)
                values=np.array(train.values.T)
                a.append(values[1])
        a=np.array(a)     
        
       
        conditioning=torch.ones(1,inputs.shape[0],condition_len)
        
        output_test=fwd_test(input_=inputs, conditioning=conditioning, b_size=inputs.shape[0])
        output_test=torch.nn.functional.normalize(output_test, p=2.0, dim = 1)
        #indices = output_test < 0.001
        #output_test[indices]=0
       
        y_truth = torch.tensor(a)
        #y_truth = torch.nn.functional.normalize(y_truth, p=2.0, dim = 1)
        
        #error
        
        errD_real = criterion(output_test.float(), y_truth.float())
        errD_real.backward()
        loss=errD_real.item()
        opt.step()
        scale = torch.tensor([10.0])

        running_loss +=loss
        loss_values.append(running_loss)


        x += 1
        i = i+1
        

        if i % 10 == 1:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {loss / 10:.3f} running loss:  {running_loss / 10:.3f}')
            running_loss = 0.0

        iters += 1
# Out:
# Epoch 0/2
# ----------
#   0%|          | 0/556 [00:00<?, ?it/s]
# [1,     2] loss: 5.772 running loss:  5.772
# [1,    12] loss: 3.743 running loss:  56.987
# [1,    22] loss: 3.518 running loss:  58.051
# [1,    32] loss: 5.623 running loss:  59.819
# [1,    42] loss: 3.003 running loss:  50.616
# [1,    52] loss: 7.392 running loss:  65.514
# [1,    62] loss: 7.137 running loss:  56.797
# [1,    72] loss: 4.703 running loss:  56.003
# [1,    82] loss: 4.043 running loss:  58.448
# [1,    92] loss: 7.330 running loss:  64.532
# [1,   102] loss: 2.242 running loss:  51.851
# [1,   112] loss: 4.071 running loss:  51.769
# [1,   122] loss: 5.188 running loss:  58.214
# [1,   132] loss: 7.188 running loss:  54.097
# [1,   142] loss: 8.582 running loss:  66.495
# [1,   152] loss: 5.130 running loss:  60.632
# [1,   162] loss: 5.941 running loss:  67.245
# [1,   172] loss: 7.365 running loss:  66.245
# [1,   182] loss: 3.960 running loss:  56.612
# [1,   192] loss: 5.766 running loss:  59.190
# [1,   202] loss: 5.845 running loss:  56.563
# [1,   212] loss: 6.515 running loss:  51.653
# [1,   222] loss: 6.581 running loss:  59.657
# [1,   232] loss: 7.096 running loss:  66.863
# [1,   242] loss: 5.146 running loss:  58.329
# [1,   252] loss: 5.143 running loss:  52.444
# [1,   262] loss: 6.309 running loss:  59.819
# [1,   272] loss: 4.298 running loss:  58.807
# [1,   282] loss: 7.935 running loss:  65.131
# [1,   292] loss: 8.408 running loss:  67.262
# [1,   302] loss: 5.955 running loss:  57.532
# [1,   312] loss: 5.664 running loss:  54.804
# [1,   322] loss: 6.314 running loss:  56.832
# [1,   332] loss: 8.066 running loss:  61.114
# [1,   342] loss: 8.310 running loss:  61.789
# [1,   352] loss: 3.365 running loss:  57.166
# [1,   362] loss: 3.602 running loss:  60.036
# [1,   372] loss: 5.334 running loss:  57.547
# [1,   382] loss: 5.878 running loss:  65.009
# [1,   392] loss: 2.556 running loss:  62.453
# [1,   402] loss: 4.486 running loss:  60.812
# [1,   412] loss: 5.919 running loss:  62.965
# [1,   422] loss: 7.915 running loss:  54.292
# [1,   432] loss: 5.752 running loss:  66.777
# [1,   442] loss: 7.115 running loss:  58.356
# [1,   452] loss: 4.121 running loss:  50.976
# [1,   462] loss: 4.403 running loss:  58.180
# [1,   472] loss: 8.231 running loss:  56.637
# [1,   482] loss: 4.119 running loss:  58.427
# [1,   492] loss: 6.857 running loss:  58.156
# [1,   502] loss: 5.066 running loss:  53.448
# [1,   512] loss: 4.713 running loss:  60.550
# [1,   522] loss: 4.078 running loss:  48.794
# [1,   532] loss: 5.888 running loss:  55.019
# [1,   542] loss: 2.142 running loss:  50.355
# [1,   552] loss: 5.203 running loss:  56.852
# Epoch 1/2
# ----------
#   0%|          | 0/556 [00:00<?, ?it/s]
# [2,     2] loss: 7.318 running loss:  7.318
# [2,    12] loss: 2.992 running loss:  52.974
# [2,    22] loss: 3.584 running loss:  53.596
# [2,    32] loss: 5.612 running loss:  60.927
# [2,    42] loss: 6.027 running loss:  54.411
# [2,    52] loss: 5.105 running loss:  56.491
# [2,    62] loss: 5.482 running loss:  45.865
# [2,    72] loss: 4.969 running loss:  51.058
# [2,    82] loss: 4.789 running loss:  60.725
# [2,    92] loss: 4.440 running loss:  59.386
# [2,   102] loss: 4.313 running loss:  59.188
# [2,   112] loss: 6.131 running loss:  58.457
# [2,   122] loss: 8.045 running loss:  61.614
# [2,   132] loss: 2.308 running loss:  57.782
# [2,   142] loss: 5.776 running loss:  59.484
# [2,   152] loss: 7.112 running loss:  54.704
# [2,   162] loss: 4.476 running loss:  54.824
# [2,   172] loss: 3.940 running loss:  58.948
# [2,   182] loss: 4.430 running loss:  59.182
# [2,   192] loss: 5.831 running loss:  63.212
# [2,   202] loss: 6.002 running loss:  56.848
# [2,   212] loss: 5.518 running loss:  54.537
# [2,   222] loss: 6.329 running loss:  56.893
# [2,   232] loss: 4.487 running loss:  54.112
# [2,   242] loss: 4.435 running loss:  61.021
# [2,   252] loss: 3.947 running loss:  61.330
# [2,   262] loss: 4.751 running loss:  50.878
# [2,   272] loss: 7.332 running loss:  53.379
# [2,   282] loss: 7.802 running loss:  59.292
# [2,   292] loss: 7.106 running loss:  61.181
# [2,   302] loss: 6.361 running loss:  55.252
# [2,   312] loss: 5.436 running loss:  60.594
# [2,   322] loss: 7.130 running loss:  64.683
# [2,   332] loss: 2.844 running loss:  57.427
# [2,   342] loss: 9.179 running loss:  61.428
# [2,   352] loss: 5.766 running loss:  56.835
# [2,   362] loss: 2.158 running loss:  52.987
# [2,   372] loss: 6.446 running loss:  64.253
# [2,   382] loss: 9.285 running loss:  65.096
# [2,   392] loss: 8.629 running loss:  64.569
# [2,   402] loss: 4.160 running loss:  57.587
# [2,   412] loss: 7.403 running loss:  62.721
# [2,   422] loss: 7.717 running loss:  69.067
# [2,   432] loss: 5.362 running loss:  61.988
# [2,   442] loss: 6.778 running loss:  54.029
# [2,   452] loss: 7.746 running loss:  61.476
# [2,   462] loss: 4.529 running loss:  63.696
# [2,   472] loss: 7.660 running loss:  64.559
# [2,   482] loss: 8.528 running loss:  58.872
# [2,   492] loss: 4.925 running loss:  54.632
# [2,   502] loss: 6.067 running loss:  55.913
# [2,   512] loss: 6.022 running loss:  61.490
# [2,   522] loss: 6.990 running loss:  54.387
# [2,   532] loss: 3.178 running loss:  56.852
# [2,   542] loss: 6.918 running loss:  57.924
# [2,   552] loss: 5.693 running loss:  60.659
# Epoch 2/2
# ----------
#   0%|          | 0/556 [00:00<?, ?it/s]
# [3,     2] loss: 2.332 running loss:  2.332
# [3,    12] loss: 5.101 running loss:  63.226
# [3,    22] loss: 5.121 running loss:  64.934
# [3,    32] loss: 4.711 running loss:  55.711
# [3,    42] loss: 3.975 running loss:  68.134
# [3,    52] loss: 4.860 running loss:  58.877
# [3,    62] loss: 3.628 running loss:  50.147
# [3,    72] loss: 5.397 running loss:  56.318
# [3,    82] loss: 8.135 running loss:  66.056
# [3,    92] loss: 6.608 running loss:  62.808
# [3,   102] loss: 5.951 running loss:  53.429
# [3,   112] loss: 4.065 running loss:  57.287
# [3,   122] loss: 9.487 running loss:  57.058
# [3,   132] loss: 4.329 running loss:  60.535
# [3,   142] loss: 7.459 running loss:  59.455
# [3,   152] loss: 6.032 running loss:  57.535
# [3,   162] loss: 4.329 running loss:  54.990
# [3,   172] loss: 3.800 running loss:  57.376
# [3,   182] loss: 6.084 running loss:  60.318
# [3,   192] loss: 5.324 running loss:  64.934
# [3,   202] loss: 5.451 running loss:  61.243
# [3,   212] loss: 6.083 running loss:  60.241
# [3,   222] loss: 5.362 running loss:  51.181
# [3,   232] loss: 4.711 running loss:  48.556
# [3,   242] loss: 6.118 running loss:  64.203
# [3,   252] loss: 5.969 running loss:  55.987
# [3,   262] loss: 5.477 running loss:  53.419
# [3,   272] loss: 6.129 running loss:  56.925
# [3,   282] loss: 6.965 running loss:  66.196
# [3,   292] loss: 6.156 running loss:  55.078
# [3,   302] loss: 6.617 running loss:  67.694
# [3,   312] loss: 4.161 running loss:  58.735
# [3,   322] loss: 4.209 running loss:  57.571
# [3,   332] loss: 4.851 running loss:  54.374
# [3,   342] loss: 4.306 running loss:  58.893
# [3,   352] loss: 4.036 running loss:  55.675
# [3,   362] loss: 7.294 running loss:  58.266
# [3,   372] loss: 3.795 running loss:  56.796
# [3,   382] loss: 5.954 running loss:  60.948
# [3,   392] loss: 6.607 running loss:  62.381
# [3,   402] loss: 5.396 running loss:  65.609
# [3,   412] loss: 4.115 running loss:  65.043
# [3,   422] loss: 6.485 running loss:  47.674
# [3,   432] loss: 3.730 running loss:  55.665
# [3,   442] loss: 8.665 running loss:  64.836
# [3,   452] loss: 4.269 running loss:  59.479
# [3,   462] loss: 3.391 running loss:  59.120
# [3,   472] loss: 3.991 running loss:  60.999
# [3,   482] loss: 7.892 running loss:  55.285
# [3,   492] loss: 4.029 running loss:  57.857
# [3,   502] loss: 4.584 running loss:  52.272
# [3,   512] loss: 5.505 running loss:  53.382
# [3,   522] loss: 5.581 running loss:  61.692
# [3,   532] loss: 4.894 running loss:  49.931
# [3,   542] loss: 5.832 running loss:  61.873
# [3,   552] loss: 5.997 running loss:  58.541

# %%
PATH = './trainedModelTM_abs.pth'
torch.save(fwd_test.state_dict(), PATH)

# %%
boxImagesPath="C:\\Users\\jorge\\Dropbox\\Public\\MetasufacesData\\testImages\\"


dataloader_test = utils.get_data_with_labels(512, 512,1.0, boxImagesPath,parser.batch_size,drop_last=False)

print(len(dataloader_test))
#Visualizing one item

#in this case we can have access to every image name match with 
#other kind of data 
#data,target,path = next(iter(dataloader))
# Out:
# 4

# %%
net = FWD(cond_input_size=condition_len,output_size=8)
net.eval()
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
len(dataloader_test)
# Out:
# 4

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

fig, axs = plt.subplots(16,2,figsize=(10,30))
#fig.suptitle('Absorption prediction vs simulated')

counter=0
    
for item in dataloader_test:
    inputs,target,names = item
    train=[]

    
    for name in names:
        series=name.split('_')[-1].split('.')[0]
        batch=name.split('_')[4]
        for name in glob.glob(DataPath+batch+'\\files\\'+'/'+metricType+'*'+series+'.csv'): 
            #loading the absorption data
            train.append(pd.read_csv(name))

    conditioning=torch.ones(1,inputs.shape[0],condition_len)

    #batch size
    output_test=net(input_=inputs, conditioning=conditioning, b_size=inputs.shape[0])

    output_to_plot=output_test.cpu().detach().numpy()
    images_to_plot = inputs.detach().cpu().permute(0, 2, 3,1).numpy()
    
    
    for i in range(len(train)):
        
        x=np.array(train[i].values.T)[0]
        y_true=np.array(train[i].values.T)[1]
        
        print(names[i])
        
        toPlot=output_to_plot[i]
        
        indices = toPlot < 0.01
        toPlot[indices]=0

        images = (images_to_plot[i] * 255).round().astype("uint8")
        pil_images = images

        axs[counter][0].imshow(pil_images)
        axs[counter][0].set_axis_off()
        
        axs[counter][1].plot(x,y_true,label="Simulated")
        axs[counter][1].plot(x,toPlot,label="Predicted")
        axs[counter][1].legend(loc="upper right")
        axs[counter, 1].set(xlabel='Freq', ylabel='Abs')
        counter=counter+1
# Out:
# box_01_freq_reflect_b6b02fee-a8bb-11ee-8e20-047c16a08772_0-280.png
# box_01_freq_reflect_7262ded2-a81d-11ee-8e0e-047c16a08772_0-266.png
# box_01_freq_reflect_b6b02fee-a8bb-11ee-8e20-047c16a08772_0-283.png
# box_01_freq_reflect_09a2f2c2-ad7f-11ee-bb2a-047c16a08772_0-129.png
# box_01_freq_reflect_09a2f2c2-ad7f-11ee-bb2a-047c16a08772_0-130.png
# box_01_freq_reflect_b6b02fee-a8bb-11ee-8e20-047c16a08772_0-458.png
# box_01_freq_reflect_7262ded2-a81d-11ee-8e0e-047c16a08772_0-11.png
# box_01_freq_reflect_d31e1e9f-a766-11ee-8b8e-047c16a08772_0-576.png
# box_01_freq_reflect_7262ded2-a81d-11ee-8e0e-047c16a08772_0-264.png
# box_01_freq_reflect_b6b02fee-a8bb-11ee-8e20-047c16a08772_0-441.png
# box_01_freq_reflect_0ed3a0e8-a653-11ee-9db6-047c16a08772_0-582.png
# box_01_freq_reflect_b6b02fee-a8bb-11ee-8e20-047c16a08772_0-38.png
# box_01_freq_reflect_b6b02fee-a8bb-11ee-8e20-047c16a08772_0-461.png
# box_01_freq_reflect_b6b02fee-a8bb-11ee-8e20-047c16a08772_0-911.png
# box_01_freq_reflect_b6b02fee-a8bb-11ee-8e20-047c16a08772_0-443.png
# box_01_freq_reflect_b6b02fee-a8bb-11ee-8e20-047c16a08772_0-60.png
# box_01_freq_reflect_b6b02fee-a8bb-11ee-8e20-047c16a08772_0-58.png
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 45
#      42 images = (images_to_plot[i] * 255).round().astype("uint8")
#      43 pil_images = images
# ---> 45 axs[counter][0].imshow(pil_images)
#      46 axs[counter][0].set_axis_off()
#      48 axs[counter][1].plot(x,y_true,label="Simulated")
#
# IndexError: index 16 is out of bounds for axis 0 with size 16

# %%
plt.plot(loss_values)
